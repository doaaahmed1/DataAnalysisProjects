# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ai_job_market_insights.csv')

# %%
df
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_Title              500 non-null    object
#  1   Industry               500 non-null    object
#  2   Company_Size           500 non-null    object
#  3   Location               500 non-null    object
#  4   AI_Adoption_Level      500 non-null    object
#  5   Automation_Risk        500 non-null    object
#  6   Required_Skills        500 non-null    object
#  7   Salary_USD             500 non-null    float64
#  8   Remote_Friendly        500 non-null    object
#  9   Job_Growth_Projection  500 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 39.2+ KB

# %%
df.describe().round(2)
# Out:
#        Salary_USD
# count      500.00
# mean     91222.39
# std      20504.29
# min      31969.53
# 25%      78511.51
# 50%      91998.20
# 75%     103971.28
# max     155209.82

# %%
df['Salary_USD'] = df['Salary_USD'].apply(lambda x: f"{x:,.2f}")

# %%
df
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills  Salary_USD  \
# ...

# %%
df['Job_Title'].unique()
# Out:
# array(['Cybersecurity Analyst', 'Marketing Specialist', 'AI Researcher',
#        'Sales Manager', 'UX Designer', 'HR Manager', 'Product Manager',
#        'Software Engineer', 'Data Scientist', 'Operations Manager'],
#       dtype=object)

# %%
def get_job_category(job_title):
    if job_title in ['Cybersecurity Analyst', 'AI Researcher', 'UX Designer', 'Software Engineer', 'Data Scientist']:
        return 'Technology & Engineering'
    elif job_title in ['Sales Manager', 'HR Manager', 'Product Manager', 'Operations Manager']:
        return 'Management'
    elif job_title == 'Marketing Specialist':
        return 'Marketing'
    else:
        return 'Unknown'  

df['Job_Category'] = df['Job_Title'].apply(get_job_category)

# %%
df
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills  Salary_USD  \
# ...

# %%
df['Required_Skills'].unique()
# Out:
# array(['UX/UI Design', 'Marketing', 'Project Management', 'JavaScript',
#        'Cybersecurity', 'Sales', 'Machine Learning', 'Python',
#        'Data Analysis', 'Communication'], dtype=object)

# %%
df['Industry'].unique()
# Out:
# array(['Entertainment', 'Technology', 'Retail', 'Education', 'Finance',
#        'Transportation', 'Telecommunications', 'Manufacturing',
#        'Healthcare', 'Energy'], dtype=object)

# %%
df['Location'].unique()
# Out:
# array(['Dubai', 'Singapore', 'Berlin', 'Tokyo', 'San Francisco', 'London',
#        'Paris', 'Sydney', 'New York', 'Toronto'], dtype=object)

# %%
def categorize_by_region(Location):
    if Location == 'Dubai':
        return 'Middle East'
    elif Location in ['Singapore', 'Tokyo']:
        return 'Asia'
    elif Location in ['Berlin', 'London', 'Paris', 'Sydney', 'Toronto']:
        return 'Europe'
    elif Location in ['New York', 'Toronto']:
        return 'North America'
    elif Location == 'Sydney':
        return 'Australia'
    else:
        return 'Unknown'

df['Region'] = df['Location'].apply(categorize_by_region)

# %%
df
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills  Salary_USD  \
# ...

# %%
from IPython.display import FileLink

# Save the DataFrame to a CSV file
df.to_csv('cleaned_data.csv', index=False)

# Create a download link with full path
FileLink('cleaned_data.csv')
# Out:
# C:\Users\Carnival\cleaned_data.csv
